# %% [markdown]
# <a href="https://colab.research.google.com/github/SamTavasoli/AAI-510-Home-Credit-Default-Risk/blob/main/notebooks/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI-510 Final Team Project (Group 3)
# ## Home Credit Default Risk Prediction
# ### Team Members
# - Ashley Figueroa
# - Jackson Kenyon
# - Saman Tavasoli

# %% [markdown]
# # 1. Problem Statement and Business Understanding

# %% [markdown]
# # 2. Dataset Understanding

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)

# %% [markdown]
# # 4. Data Preparation and Feature Engineering

# %% [markdown]
# # 5. Feature Selection

# %% [markdown]
# # 6. Modeling

# %% [markdown]
# ## 6.1 Decision Tree

# %% [markdown]
# ## 6.2 Random Forest

# %% [markdown]
# ## 6.3 XGBoost

# %% [markdown]
# # 7. Model Evaluation and Comparison

# %% [markdown]
# # 8. Business Recommendations

# %% [markdown]
# # 9. Deployment Discussion

# %% [markdown]
# # 10. Conclusion
